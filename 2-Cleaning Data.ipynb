# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil import tz
import pytz
from scipy import stats
# %matplotlib inline
pd.set_option("display.max_rows", 15)

# %%
energy = pd.read_csv("Energy.csv")
daytimes = pd.read_csv("Daytimes.csv")
weather = pd.read_csv("Weather.csv")
weather
# Out:
#         air_temp_set_1          date_time  pressure_set_1d  \
# 0                 14.4  Y2013M10D14H00M51         99775.27
# 1                 12.0  Y2013M10D14H01M43         99841.78
# 2                 12.2  Y2013M10D14H01M51         99841.78
# 3                 12.2  Y2013M10D14H02M51         99875.05
# 4                 12.8  Y2013M10D14H03M51         99908.31
# 5                 12.8  Y2013M10D14H04M51         99941.56
# 6                 12.0  Y2013M10D14H05M49         99941.56
# ...                ...                ...              ...
# 129388            18.0  Y2017M05D09H19M35        100367.33
# 129389            18.0  Y2017M05D09H19M40        100367.33
# 129390            18.0  Y2017M05D09H19M45        100367.33
# 129391            18.0  Y2017M05D09H19M50        100400.90
# 129392            18.0  Y2017M05D09H19M51        100367.33
# 129393            19.0  Y2017M05D09H19M55        100367.33
# 129394            19.0  Y2017M05D09H20M00        100367.33
#
#         relative_humidity_set_1 weather_condition_set_1d  wind_speed_set_1
# 0                         77.94            Partly Cloudy              4.63
# 1                         87.57            Mostly Cloudy              1.54
# 2                         86.42            Mostly Cloudy              3.09
# 3                         89.96                 Overcast              0.00
# 4                         86.49                 Overcast              0.00
# 5                         86.49                      Fog              1.54
# 6                         87.57                      Fog              1.54
# ...                         ...                      ...               ...
# 129388                    67.99                      NaN              3.09
# 129389                    67.99                      NaN              3.60
# 129390                    67.99                      NaN              3.09
# 129391                    67.99                      NaN              3.09
# 129392                    67.99                      NaN              3.60
# 129393                    68.20                      NaN              3.09
# 129394                    63.87                      NaN              4.12
#
# [129395 rows x 6 columns]

# %%
#convert UTC time to local time so that sunsise and sunset times are on the same date.
local = pytz.timezone("US/Pacific")

weather.date_time = pd.to_datetime(weather.date_time, format='Y%YM%mD%dH%HM%M',utc = True)
weather.date_time = weather.date_time.dt.tz_localize(pytz.utc).dt.tz_convert(local)

daytimes.sunrise = pd.to_datetime(daytimes.sunrise, format='%Y-%m-%dT%H:%M:%S')
daytimes.sunset = pd.to_datetime(daytimes.sunset, format='%Y-%m-%dT%H:%M:%S')
daytimes.sunset = daytimes.sunset.dt.tz_localize(pytz.utc).dt.tz_convert(local)
daytimes.sunrise = daytimes.sunrise.dt.tz_localize(pytz.utc).dt.tz_convert(local)

#weather.head(), daytimes.head()

# %%
#remove nightime weather readings by removing readings taken before sunrise and after sunset.
daytimes["Date"] = daytimes.sunrise.dt.date
weather["Date"]= weather.date_time.dt.date

merged = weather.merge(daytimes, on="Date")
daytime_weather = merged.loc[(merged.sunrise.dt.time <= merged.date_time.dt.time)& (merged.sunset.dt.time >= merged.date_time.dt.time), :]

# %%
#Aggregate the quantitative variables accross days
weather_quantitative = daytime_weather.groupby(daytime_weather.date_time.dt.date).mean()

# %%
weather_quantitative.head()
# Out:
#             air_temp_set_1  pressure_set_1d  relative_humidity_set_1  \
# date_time
# 2013-10-14       21.563636     99778.295455                40.475455
# 2013-10-15       24.841667     99542.463333                27.645833
# 2013-10-16       24.836364     99914.350909                23.462727
# 2013-10-17       21.409091     99766.200000                32.283636
# 2013-10-18       22.281818     99760.157273                37.134545
#
#             wind_speed_set_1  day_length
# date_time
# 2013-10-14          3.740909       40786
# 2013-10-15          3.215000       40660
# 2013-10-16          3.085455       40533
# 2013-10-17          4.020909       40407
# 2013-10-18          2.431818       40283

# %%
#Aggregate categorical weather condition at the day level:
#the most frequent weather condition of the day is set as that day's weather condition
mostfreq_weather = {
    "Date":[],
    "Weather_overall": []
}
days = daytime_weather.groupby(daytime_weather.date_time.dt.date)
for day in days:
    mostfreq_weather["Date"].append(day[0])
    weather_label = list(day[1]["weather_condition_set_1d"].mode())
    if len(weather_label)>0:
        mostfreq_weather["Weather_overall"].append(weather_label[0])
    else:
        mostfreq_weather["Weather_overall"].append(np.nan)
agg_weather_condition = pd.DataFrame(mostfreq_weather)

# %%
#Create quantitative daily values to express the cloud cover.
weather_cats = daytime_weather.groupby(daytime_weather.date_time.dt.date)["weather_condition_set_1d"].value_counts(dropna = False).unstack()
weather_cats.head()
# Out:
# weather_condition_set_1d  NaN  Blowing Dust  Clear  Fog  Haze  \
# date_time
# 2013-10-14                NaN           NaN   11.0  NaN   NaN
# 2013-10-15                NaN           NaN   12.0  NaN   NaN
# 2013-10-16                NaN           NaN   11.0  NaN   NaN
# 2013-10-17                NaN           NaN   11.0  NaN   NaN
# 2013-10-18                NaN           NaN   11.0  NaN   NaN
#
# weather_condition_set_1d  Haze,Blowing Dust  Heavy Rain  Heavy Rain,Fog  \
# date_time
# 2013-10-14                              NaN         NaN             NaN
# 2013-10-15                              NaN         NaN             NaN
# 2013-10-16                              NaN         NaN             NaN
# 2013-10-17                              NaN         NaN             NaN
# 2013-10-18                              NaN         NaN             NaN
#
# weather_condition_set_1d  Heavy Rain,Hail  Heavy Rain/Thunderstorm,Fog  \
# date_time
# 2013-10-14                            NaN                          NaN
# 2013-10-15                            NaN                          NaN
# 2013-10-16                            NaN                          NaN
# 2013-10-17                            NaN                          NaN
# 2013-10-18                            NaN                          NaN
#
# weather_condition_set_1d        ...          Partly Cloudy  Rain  Rain,Fog  \
# date_time                       ...
# 2013-10-14                      ...                    NaN   NaN       NaN
# 2013-10-15                      ...                    NaN   NaN       NaN
# 2013-10-16                      ...                    NaN   NaN       NaN
# 2013-10-17                      ...                    NaN   NaN       NaN
# 2013-10-18                      ...                    NaN   NaN       NaN
#
# weather_condition_set_1d  Sky Obscured  Smoke  Smoke,Blowing Dust  Thunder  \
# date_time
# 2013-10-14                         NaN    NaN                 NaN      NaN
# 2013-10-15                         NaN    NaN                 NaN      NaN
# 2013-10-16                         NaN    NaN                 NaN      NaN
# 2013-10-17                         NaN    NaN                 NaN      NaN
# 2013-10-18                         NaN    NaN                 NaN      NaN
#
# weather_condition_set_1d  Thunderstorm  Thunderstorm,Fog  Thunderstorm,Hail
# date_time
# 2013-10-14                         NaN               NaN                NaN
# 2013-10-15                         NaN               NaN                NaN
# 2013-10-16                         NaN               NaN                NaN
# 2013-10-17                         NaN               NaN                NaN
# 2013-10-18                         NaN               NaN                NaN
#
# [5 rows x 26 columns]

# %%
weather_cats["total"] = weather_cats.sum(axis = 1)
weather_cats.columns
# Out:
# Index([                          nan,                'Blowing Dust',
#                              'Clear',                         'Fog',
#                               'Haze',           'Haze,Blowing Dust',
#                         'Heavy Rain',              'Heavy Rain,Fog',
#                    'Heavy Rain,Hail', 'Heavy Rain/Thunderstorm,Fog',
#                         'Light Rain',              'Light Rain,Fog',
#            'Light Rain/Thunderstorm',                'Mostly Clear',
#                      'Mostly Cloudy',                    'Overcast',
#                      'Partly Cloudy',                        'Rain',
#                           'Rain,Fog',                'Sky Obscured',
#                              'Smoke',          'Smoke,Blowing Dust',
#                            'Thunder',                'Thunderstorm',
#                   'Thunderstorm,Fog',           'Thunderstorm,Hail',
#                              'total'],
#       dtype='object', name='weather_condition_set_1d')

# %%
weather_type_percentages = pd.DataFrame()
for column in weather_cats.loc[:, "Blowing Dust":"Thunderstorm,Hail"].columns:
    name = "pct_"+column
    weather_type_percentages[name] =( weather_cats[column] / weather_cats.total)*100

# %%
weather_type_percentages.head()
# Out:
#             pct_Blowing Dust  pct_Clear  pct_Fog  pct_Haze  \
# date_time
# 2013-10-14               NaN      100.0      NaN       NaN
# 2013-10-15               NaN      100.0      NaN       NaN
# 2013-10-16               NaN      100.0      NaN       NaN
# 2013-10-17               NaN      100.0      NaN       NaN
# 2013-10-18               NaN      100.0      NaN       NaN
#
#             pct_Haze,Blowing Dust  pct_Heavy Rain  pct_Heavy Rain,Fog  \
# date_time
# 2013-10-14                    NaN             NaN                 NaN
# 2013-10-15                    NaN             NaN                 NaN
# 2013-10-16                    NaN             NaN                 NaN
# 2013-10-17                    NaN             NaN                 NaN
# 2013-10-18                    NaN             NaN                 NaN
#
#             pct_Heavy Rain,Hail  pct_Heavy Rain/Thunderstorm,Fog  \
# date_time
# 2013-10-14                  NaN                              NaN
# 2013-10-15                  NaN                              NaN
# 2013-10-16                  NaN                              NaN
# 2013-10-17                  NaN                              NaN
# 2013-10-18                  NaN                              NaN
#
#             pct_Light Rain          ...            pct_Partly Cloudy  \
# date_time                           ...
# 2013-10-14             NaN          ...                          NaN
# 2013-10-15             NaN          ...                          NaN
# 2013-10-16             NaN          ...                          NaN
# 2013-10-17             NaN          ...                          NaN
# 2013-10-18             NaN          ...                          NaN
#
#             pct_Rain  pct_Rain,Fog  pct_Sky Obscured  pct_Smoke  \
# date_time
# 2013-10-14       NaN           NaN               NaN        NaN
# 2013-10-15       NaN           NaN               NaN        NaN
# 2013-10-16       NaN           NaN               NaN        NaN
# 2013-10-17       NaN           NaN               NaN        NaN
# 2013-10-18       NaN           NaN               NaN        NaN
#
#             pct_Smoke,Blowing Dust  pct_Thunder  pct_Thunderstorm  \
# date_time
# 2013-10-14                     NaN          NaN               NaN
# 2013-10-15                     NaN          NaN               NaN
# 2013-10-16                     NaN          NaN               NaN
# 2013-10-17                     NaN          NaN               NaN
# 2013-10-18                     NaN          NaN               NaN
#
#             pct_Thunderstorm,Fog  pct_Thunderstorm,Hail
# date_time
# 2013-10-14                   NaN                    NaN
# 2013-10-15                   NaN                    NaN
# 2013-10-16                   NaN                    NaN
# 2013-10-17                   NaN                    NaN
# 2013-10-18                   NaN                    NaN
#
# [5 rows x 25 columns]

# %%
weather_quantitative = weather_quantitative.merge(agg_weather_condition, right_on="Date", left_index=True)

# %%
final_weather_data = weather_quantitative.merge(weather_type_percentages, right_index=True, left_on="Date")
final_weather_data
# Out:
#       air_temp_set_1  pressure_set_1d  relative_humidity_set_1  \
# 0          21.563636     99778.295455                40.475455
# 1          24.841667     99542.463333                27.645833
# 2          24.836364     99914.350909                23.462727
# 3          21.409091     99766.200000                32.283636
# 4          22.281818     99760.157273                37.134545
# 5          14.714286     99865.542143                70.527857
# 6          14.100000     99703.212778                76.987222
# ...              ...              ...                      ...
# 1297       20.500000    100533.527378                65.505488
# 1298       16.400578    100585.809769                80.101156
# 1299       14.250279    100389.271229                86.218883
# 1300       12.648876    100208.919213                68.890169
# 1301       12.224022    100248.999218                85.262067
# 1302       14.105435    100511.086087                80.578315
# 1303       13.209574    100305.193830                88.384681
#
#       wind_speed_set_1  day_length        Date Weather_overall  \
# 0             3.740909       40786  2013-10-14           Clear
# 1             3.215000       40660  2013-10-15           Clear
# 2             3.085455       40533  2013-10-16           Clear
# 3             4.020909       40407  2013-10-17           Clear
# 4             2.431818       40283  2013-10-18           Clear
# 5             1.947857       40158  2013-10-19           Clear
# 6             1.771667       40034  2013-10-20            Haze
# ...                ...         ...         ...             ...
# 1297          2.841890       49302  2017-05-03            Haze
# 1298          2.988960       49410  2017-05-04           Clear
# 1299          3.734689       49515  2017-05-05             Fog
# 1300          8.586629       49621  2017-05-06            Haze
# 1301          3.313687       49724  2017-05-07        Overcast
# 1302          4.182446       49826  2017-05-08             NaN
# 1303          2.309787       49927  2017-05-09             NaN
#
#       pct_Blowing Dust   pct_Clear    pct_Fog          ...            \
# 0                  NaN  100.000000        NaN          ...
# 1                  NaN  100.000000        NaN          ...
# 2                  NaN  100.000000        NaN          ...
# 3                  NaN  100.000000        NaN          ...
# 4                  NaN  100.000000        NaN          ...
# 5                  NaN   57.142857  35.714286          ...
# 6                  NaN   22.222222  33.333333          ...
# ...                ...         ...        ...          ...
# 1297               NaN    3.954802  11.864407          ...
# 1298               NaN   42.857143  40.109890          ...
# 1299               NaN    7.065217  39.673913          ...
# 1300               NaN         NaN  18.131868          ...
# 1301               NaN    1.092896   6.557377          ...
# 1302               NaN         NaN        NaN          ...
# 1303               NaN         NaN        NaN          ...
#
#       pct_Partly Cloudy  pct_Rain  pct_Rain,Fog  pct_Sky Obscured  pct_Smoke  \
# 0                   NaN       NaN           NaN               NaN        NaN
# 1                   NaN       NaN           NaN               NaN        NaN
# 2                   NaN       NaN           NaN               NaN        NaN
# 3                   NaN       NaN           NaN               NaN        NaN
# 4                   NaN       NaN           NaN               NaN        NaN
# 5                   NaN       NaN           NaN               NaN        NaN
# 6              5.555556       NaN           NaN               NaN        NaN
# ...                 ...       ...           ...               ...        ...
# 1297                NaN       NaN           NaN               NaN        NaN
# 1298           1.098901       NaN           NaN               NaN        NaN
# 1299           3.804348       NaN           NaN               NaN        NaN
# 1300                NaN       NaN           NaN               NaN        NaN
# 1301           0.546448       NaN      6.557377               NaN        NaN
# 1302                NaN       NaN           NaN               NaN        NaN
# 1303                NaN       NaN           NaN               NaN        NaN
#
#       pct_Smoke,Blowing Dust  pct_Thunder  pct_Thunderstorm  \
# 0                        NaN          NaN               NaN
# 1                        NaN          NaN               NaN
# 2                        NaN          NaN               NaN
# 3                        NaN          NaN               NaN
# 4                        NaN          NaN               NaN
# 5                        NaN          NaN               NaN
# 6                        NaN          NaN               NaN
# ...                      ...          ...               ...
# 1297                     NaN          NaN               NaN
# 1298                     NaN          NaN               NaN
# 1299                     NaN          NaN               NaN
# 1300                     NaN          NaN               NaN
# 1301                     NaN          NaN               NaN
# 1302                     NaN          NaN               NaN
# 1303                     NaN          NaN               NaN
#
#       pct_Thunderstorm,Fog  pct_Thunderstorm,Hail
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# 5                      NaN                    NaN
# 6                      NaN                    NaN
# ...                    ...                    ...
# 1297                   NaN                    NaN
# 1298                   NaN                    NaN
# 1299                   NaN                    NaN
# 1300                   NaN                    NaN
# 1301                   NaN                    NaN
# 1302                   NaN                    NaN
# 1303                   NaN                    NaN
#
# [1304 rows x 32 columns]

# %%
energy["Dateobs"] = pd.to_datetime(energy[['Year', 'Month', 'Day']])

energy.Date = energy.Dateobs.dt.date
final_data = energy.merge(final_weather_data, right_on="Date", left_on="Date")

# %%
#The first day was an outlier since we finished installing the solar panels that afternoon so it is dropped. 
final_data.drop(0, axis = 0, inplace=True)

# %%
final_data.columns
# Out:
# Index(['Date/Time', 'Energy Produced (Wh)', 'Year', 'Month', 'Day', 'Date',
#        'Dateobs', 'air_temp_set_1', 'pressure_set_1d',
#        'relative_humidity_set_1', 'wind_speed_set_1', 'day_length',
#        'Weather_overall', 'pct_Blowing Dust', 'pct_Clear', 'pct_Fog',
#        'pct_Haze', 'pct_Haze,Blowing Dust', 'pct_Heavy Rain',
#        'pct_Heavy Rain,Fog', 'pct_Heavy Rain,Hail',
#        'pct_Heavy Rain/Thunderstorm,Fog', 'pct_Light Rain',
#        'pct_Light Rain,Fog', 'pct_Light Rain/Thunderstorm', 'pct_Mostly Clear',
#        'pct_Mostly Cloudy', 'pct_Overcast', 'pct_Partly Cloudy', 'pct_Rain',
#        'pct_Rain,Fog', 'pct_Sky Obscured', 'pct_Smoke',
#        'pct_Smoke,Blowing Dust', 'pct_Thunder', 'pct_Thunderstorm',
#        'pct_Thunderstorm,Fog', 'pct_Thunderstorm,Hail'],
#       dtype='object')

# %%
# !pwd
# Out:
# /home/tmgerrit/Data301/Final Project

# %%
final_data.to_csv("/home/tmgerrit/Data301/Final Project/cleaned_data.csv", index=False)
